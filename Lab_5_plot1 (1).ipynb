# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import os

# %%
os.chdir("C:/Users/Lucas Lostie/Documents/McGill/phys 257/lab5")
data = np.transpose(np.genfromtxt("lab5.csv",delimiter = ","))

x = data[0]
y = data[2]

x_err = data[1]
y_err = data[3]

y_err
# Out:
# array([0.005, 0.005, 0.005, 0.01 , 0.02 , 0.05 , 0.006, 0.007, 0.009,
#        0.006, 0.005])

# %%
# Perform linear fit using NumPy's polyfit
coefficients = np.polyfit(x, y, 1)
slope, intercept = coefficients

# Calculate residuals
residuals = y - (slope * x + intercept)



plt.figure(figsize=(12, 5))

# First subplot: Data Points with Linear Fit
plt.subplot(1, 2, 1)
plt.errorbar(x, y, yerr=y_err*100, xerr=x_err, fmt='o', label='Data Points with Uncertainties (x100)')
plt.plot(x_fit, y_fit, color='red', label='Linear Fit')
plt.xlabel('Velocity (cm/s)')
plt.ylabel('Accelration (m/s2)')
plt.title('Data and Linear Fit')
plt.legend()

# Second subplot: Residuals
plt.subplot(1, 2, 2)
plt.errorbar(x, residuals, yerr=y_err, fmt='o', label='Residuals')
plt.axhline(0, color='red', linestyle='--', label='Zero Residual Line')
plt.xlabel('Velocity (cm/s)')
plt.ylabel('Residuals')
plt.title('Residuals')
plt.legend()

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# Print the slope and intercept of the linear fit
print(f"Slope (m): {slope}")
print(f"Intercept (b): {intercept}")
# Out:
# Slope (m): 0.05442528054558485
# Intercept (b): 0.48852364023548567
